# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - List of popular languages for Data Science
# - List of commonly used liraries by Data Scientists
# - List of Data Science Tools
# - Examples of evaluating arithmetic expressions in Python

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R Programming
# 3. SQL
# 4. Java
# 5. Scala
# 6. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow
# 6. Keras

# %% [markdown]
# | Data Science Tools |
# | --- |
# | Jupyter Notebook |
# | RStudio |
# | PyCharm |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# - Addition: 2 + 3 evaluates to 5.
# - Subtraction: 7 - 4 evaluates to 3.
# - Multiplication: 5 * 6 evaluates to 30.
# - Division: 10 / 2 evaluates to 5.0 (note that Python 3 returns a float by default for division).

# %%
# This a simple arithmetic expression to mutiply then add integers
result = (3*4)+5
print(result)
# Out:
# 17

# %%
minutes = 200
# This will convert 200 minutes to hours by diving by 60
hour = 200/60
print(hour)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Bharathwaj Nedoumaran
